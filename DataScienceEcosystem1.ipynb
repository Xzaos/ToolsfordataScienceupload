# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # DataScienceEcosystem
# 2-Title.png![image.png](attachment:image.png)

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarised
# 3-intro.png![image.png](attachment:image.png)

# %% [markdown]
# ### Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Javascript
# 4. C++
# 4-dslanguages.png ![image.png](attachment:image.png)

# %% [markdown]
# ### Some of the commonly used libraries by Data Scientists include:
# 1. Numpy
# 2. scikit-learn
# 3. matplotlib
# 4. pandas
#
# 5-dslibraries.png![image.png](attachment:image.png)

# %% [markdown]
# |Data Science Tools |
# | ------ |
# |Python |
# |R |
# |Github |
# |Numpy |
#
# 6-dstools.png![image.png](attachment:image.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# 7-introarithmetic.png ![image.png](attachment:image.png)

# %%
# this is a simple arithmetic expression to multiply and then add integers
# print(3*4+5)
print(3*4+5)
# Out:
# 17

# %% [markdown]
# 8-multiplyandaddintegers.png ![image.png](attachment:image.png)

# %%
# This will convert 200 minutes into hours by dividing by 60
minutes=200
print("Hours: ",200/60)
# Out:
# Hours:  3.3333333333333335

# %% [markdown]
# 9-hourstominutes.png![image.png](attachment:image.png)

# %% [markdown]
# __Objectives:__
# * Data Science languages
# * Data Science libraries
# * Data Science open source tools

# %% [markdown]
# 10-objectives.png![image.png](attachment:image.png)

# %% [markdown]
# ## Author
# Ritwik Mishra
#
# 11-authordetails![image.png](attachment:image.png)
